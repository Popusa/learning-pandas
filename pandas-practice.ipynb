# %% [markdown]
# ### Learning Pandas from Corey Schafer

# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv",index_col = 'Respondent');
schema_df = pd.read_csv("survey_results_schema.csv",index_col = 'Column');

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df[['Respondent','OpenSource','Country','Student']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12480/2108910761.py in <module>
# ----> 1 df[['Respondent','OpenSource','Country','Student']]
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df.columns

# %%
df.iloc[0:5]

# %%
df.loc[0:500,['Hobbyist','Country']]

# %%
df.shape

# %%
df.info()

# %%
df[df['Hobbyist'] == 'Yes'].iloc[500]

# %%
schema_df.head()

# %%
schema_df.head(30)

# %%
schema_df.sort_index(ascending = False, inplace = True)

# %%
df[df['Hobbyist'] == "Yes"].loc[1:500]

# %%
df.loc[df['Hobbyist'] == 'Yes']

# %%
filt = df['Hobbyist'] == 'Yes'

# %%
df[filt]

# %%
df.loc[filt,'MgrIdiot']

# %%
filt_two = (df['Hobbyist'] == 'Yes') & (df['MgrIdiot'].str.contains('Somewhat'))

# %%
df.loc[~filt_two]

# %%
df.head()

# %%
schema_df.loc['FizzBuzz',"QuestionText"]

# %%
df.head(20)

# %%
rows_count = df.shape[0]

# %%
percent_asked_fizzbuzz = (asked_fizzbuzz / rows_count) * 100

# %%
percent_asked_fizzbuzz

# %%
high_salary = df['ConvertedComp'] > 80000

# %%
df.loc[high_salary]

# %%
df.head()

# %%
df.loc[df['LanguageWorkedWith'].str.contains('Python',na = False),'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[2,['Hobbyist','Country']] = ['Absolutely','Egypt']

df.loc[2]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                         Absolutely
# OpenSourcer                                         Less than once per year
# OpenSource                The quality of OSS and closed source software ...
# Employment                               Not employed, but looking for work
# Country                                                               Egypt
# Student                                                      Yes, full-time
# EdLevel                   Secondary school (e.g. American high school, G...
# UndergradMajor                                                          NaN
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                                 NaN
# DevType                   Developer, desktop or enterprise applications;...
# ...

# %%
df['Student'].apply(str.lower)
# Out:
# Respondent
# 1                    no
# 2        yes, full-time
# 3                    no
# 4                    no
# 5                    no
#               ...
# 88377                no
# 88601               nan
# 88802               nan
# 88816               nan
# 88863    yes, full-time
# Name: Student, Length: 88883, dtype: object

# %%
df['Hobbyist'].replace({'Yes':'Absolutely','No':'Negatory'},inplace = True)

# %%
df.rename(columns = {'ConvertedComp':'Salary'},inplace = True)

# %%
df['Hobbyist_Student'] = (df['Hobbyist'] == 'Absolutely') & df['Student'].str.contains('Yes')

df.head()
# Out:
#                                                    MainBranch    Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code  Absolutely
# 2                      I am a student who is learning to code  Absolutely
# 3           I am not primarily a developer, but I write co...  Absolutely
# 4                              I am a developer by profession    Negatory
# 5                              I am a developer by profession  Absolutely
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# ...

# %%
df.drop(columns = 'Hobbyist_Student',axis = 'Column',inplace = False)
# Out:
#                                                    MainBranch    Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code  Absolutely
# 2                      I am a student who is learning to code  Absolutely
# 3           I am not primarily a developer, but I write co...  Absolutely
# 4                              I am a developer by profession    Negatory
# 5                              I am a developer by profession  Absolutely
# ...                                                       ...         ...
# 88377                                                     NaN  Absolutely
# 88601                                                     NaN    Negatory
# 88802                                                     NaN    Negatory
# 88816                                                     NaN    Negatory
# 88863                                                     NaN  Absolutely
#
#                                                   OpenSourcer  \
# ...

# %%
df.sort_values(by=['Salary','Country'],ascending = [False,True],inplace = True)

df.head(40)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
# 84390                          I am a developer by profession      True
# 58                             I am a developer by profession      True
# ...

# %%
df['Hobbyist'].replace({'Absolutely':True,'Negatory':False},inplace = True)

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2         True
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool
